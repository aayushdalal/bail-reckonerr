# %% [markdown]
# Importing libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# importing dataset

# %%
df = pd.read_csv('bail_decision_dataset.csv')
df.shape
# Out:
# (2000, 8)

# %%
df.head()
# Out:
#      Crime_Type                                      Charges_Filed  \
# 0   Cyber Crime                  ['IPC 379', 'IPC 307', 'IPC 302']
# 1  Drug-related                 ['Narcotics Act', 'Narcotics Act']
# 2      Economic                                     ['Cyber Laws']
# 3  Drug-related                                        ['IPC 307']
# 4  Drug-related  ['Economic Offenses Act', 'Narcotics Act', 'IP...
#
#    Time_Served_Months  Prior_Criminal_History  Risk_of_Flight  \
# 0                  33                       0        0.945674
# 1                   7                       0        0.408927
# 2                  41                       0        0.661970
# 3                   8                       0        0.464855
# 4                  37                       1        0.630589
#
#    Influence_on_Trial Bail_Decision Socio_Economic_Status
# 0            0.115675      Rejected                   Low
# 1            0.946264       Granted                   Low
# 2            0.733362       Granted                  High
# 3            0.637499       Granted                  High
# 4            0.645278       Granted                   Low

# %%
df.isna().sum()
# Out:
# Crime_Type                0
# Charges_Filed             0
# Time_Served_Months        0
# Prior_Criminal_History    0
# Risk_of_Flight            0
# Influence_on_Trial        0
# Bail_Decision             0
# Socio_Economic_Status     0
# dtype: int64

# %% [markdown]
# There are 142 rows with no entry in Influence _on _Trial column, so to handle them I will fill the empty values with 'nit' means No_Influence_on_Trial.

# %%
df['Influence_on_Trial'].fillna('nit', inplace =True)

# %%
df.isna().sum()
# Out:
# Crime_Type                0
# Charges_Filed             0
# Time_Served_Months        0
# Prior_Criminal_History    0
# Risk_of_Flight            0
# Influence_on_Trial        0
# Bail_Decision             0
# Socio_Economic_Status     0
# dtype: int64

# %% [markdown]
# Now no column have missing values, so we are good to go.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicate values in the data set

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Crime_Type              2000 non-null   object
#  1   Charges_Filed           2000 non-null   object
#  2   Time_Served_Months      2000 non-null   int64
#  3   Prior_Criminal_History  2000 non-null   int64
#  4   Risk_of_Flight          2000 non-null   float64
#  5   Influence_on_Trial      2000 non-null   float64
#  6   Bail_Decision           2000 non-null   object
#  7   Socio_Economic_Status   2000 non-null   object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 125.1+ KB

# %%
df.nunique()
# Out:
# Crime_Type                   5
# Charges_Filed              347
# Time_Served_Months          47
# Prior_Criminal_History       2
# Risk_of_Flight            2000
# Influence_on_Trial        2000
# Bail_Decision                2
# Socio_Economic_Status        3
# dtype: int64

# %%
df.describe()
# Out:
#        Time_Served_Months  Prior_Criminal_History  Risk_of_Flight  \
# count         2000.000000             2000.000000     2000.000000
# mean            23.995000                0.491500        0.489680
# std             13.457397                0.500053        0.283041
# min              1.000000                0.000000        0.000053
# 25%             12.000000                0.000000        0.252218
# 50%             24.000000                0.000000        0.485669
# 75%             36.000000                1.000000        0.724911
# max             47.000000                1.000000        0.998617
#
#        Influence_on_Trial
# count         2000.000000
# mean             0.504145
# std              0.286691
# min              0.000241
# 25%              0.254909
# 50%              0.504264
# 75%              0.754456
# max              0.999673

# %%
df.head()
# Out:
#      Crime_Type                                      Charges_Filed  \
# 0   Cyber Crime                  ['IPC 379', 'IPC 307', 'IPC 302']
# 1  Drug-related                 ['Narcotics Act', 'Narcotics Act']
# 2      Economic                                     ['Cyber Laws']
# 3  Drug-related                                        ['IPC 307']
# 4  Drug-related  ['Economic Offenses Act', 'Narcotics Act', 'IP...
#
#    Time_Served_Months  Prior_Criminal_History  Risk_of_Flight  \
# 0                  33                       0        0.945674
# 1                   7                       0        0.408927
# 2                  41                       0        0.661970
# 3                   8                       0        0.464855
# 4                  37                       1        0.630589
#
#    Influence_on_Trial Bail_Decision Socio_Economic_Status
# 0            0.115675      Rejected                   Low
# 1            0.946264       Granted                   Low
# 2            0.733362       Granted                  High
# 3            0.637499       Granted                  High
# 4            0.645278       Granted                   Low

# %%
print("Categories in 'Crime_Type' variable:     ",end=" " )
print(df['Crime_Type'].unique())

print("Categories in 'Charges_Filed' variable:  ",end=" ")
print(df['Charges_Filed'].unique())

print("Categories in'parental level of education' Prior_Criminal_History:",end=" " )
print(df['Prior_Criminal_History'].unique())

print("Categories in 'Influence_on_Trial' variable:     ",end=" " )
print(df['Influence_on_Trial'].unique())

print("Categories in 'Bail_Decision' variable:     ",end=" " )
print(df['Bail_Decision'].unique())

print("Categories in 'Socio_Economic_Status' variable:     ",end=" " )
print(df['Socio_Economic_Status'].unique())
# Out:
# Categories in 'Crime_Type' variable:      ['Cyber Crime' 'Drug-related' 'Economic' 'Non-violent' 'Violent']
# Categories in 'Charges_Filed' variable:   ["['IPC 379', 'IPC 307', 'IPC 302']" "['Narcotics Act', 'Narcotics Act']"
#  "['Cyber Laws']" "['IPC 307']"
#  "['Economic Offenses Act', 'Narcotics Act', 'IPC 307']"
#  "['IPC 307', 'Cyber Laws', 'Narcotics Act']"
#  "['IPC 302', 'IPC 302', 'IPC 379']"
#  "['IPC 420', 'Cyber Laws', 'IPC 379']" "['Cyber Laws', 'IPC 307']"
#  "['Narcotics Act', 'Cyber Laws', 'IPC 420']" "['IPC 302']"
#  "['IPC 302', 'Economic Offenses Act']" "['IPC 420', 'Narcotics Act']"
#  "['Narcotics Act', 'Cyber Laws', 'IPC 307']"
#  "['Cyber Laws', 'IPC 420', 'Narcotics Act']" "['IPC 379', 'Cyber Laws']"
#  "['IPC 307', 'Economic Offenses Act']" "['Cyber Laws', 'IPC 302']"
#  "['IPC 307', 'Economic Offenses Act', 'Cyber Laws']"
#  "['IPC 420', 'IPC 307']" "['Narcotics Act']" "['Economic Offenses Act']"
#  "['IPC 302', 'Economic Offenses Act', 'IPC 307']"
#  "['IPC 420', 'IPC 302', 'IPC 420']"
#  "['Cyber Laws', 'Narcotics Act', 'Economic Offenses Act']"
#  "['Cyber Laws', 'Narcotics Act', 'IPC 420']"
#  "['Narcotics Act', 'IPC 420']" "['IPC 302', 'Narcotics Act', 'IPC 420']"
#  "['Narcotics Act', 'IPC 307']" "['IPC 379', 'IPC 302']"
#  "['IPC 379', 'IPC 420', 'Cyber Laws']"
#  "['IPC 307', 'IPC 420', 'IPC 307']"
#  "['Cyber Laws', 'IPC 379', 'Cyber Laws']"
#  "['Economic Offenses Act', 'Cyber Laws', 'IPC 420']" "['IPC 420']"
#  "['IPC 420', 'Economic Offenses Act']" "['IPC 307', 'Narcotics Act']"
#  "['Cyber Laws', 'IPC 307', 'Cyber Laws']" "['Cyber Laws', 'IPC 379']"
#  "['IPC 420', 'Cyber Laws', 'IPC 302']"
#  "['Narcotics Act', 'IPC 379', 'IPC 307']"
#  "['IPC 307', 'IPC 379', 'IPC 307']" "['IPC 302', 'IPC 307']"
#  "['IPC 302', 'IPC 420']" "['Cyber Laws', 'IPC 302', 'Cyber Laws']"
#  "['Cyber Laws', 'Narcotics Act']" "['IPC 379', 'IPC 302', 'Cyber Laws']"
#  "['Cyber Laws', 'Narcotics Act', 'IPC 379']" "['IPC 307', 'IPC 420']"
#  "['IPC 379', 'Economic Offenses Act', 'IPC 379']" "['IPC 379']"
#  "['IPC 307', 'IPC 302']" "['Narcotics Act', 'Economic Offenses Act']"
#  "['IPC 302', 'Economic Offenses Act', 'IPC 379']"
#  "['IPC 302', 'Narcotics Act', 'Economic Offenses Act']"
#  "['Economic Offenses Act', 'IPC 307']"
#  "['Narcotics Act', 'IPC 420', 'Economic Offenses Act']"
#  "['Narcotics Act', 'IPC 379']"
#  "['Economic Offenses Act', 'Narcotics Act']"
#  "['IPC 307', 'Cyber Laws', 'IPC 379']"
#  "['Narcotics Act', 'IPC 302', 'Narcotics Act']"
#  "['Economic Offenses Act', 'Narcotics Act', 'IPC 420']"
#  "['Narcotics Act', 'IPC 307', 'Cyber Laws']" "['IPC 420', 'IPC 420']"
#  "['IPC 307', 'IPC 307']"
#  "['Economic Offenses Act', 'IPC 307', 'IPC 379']"
#  "['Narcotics Act', 'IPC 379', 'Narcotics Act']"
#  "['IPC 302', 'Narcotics Act', 'IPC 379']"
#  "['Cyber Laws', 'IPC 420', 'IPC 379']"
#  "['IPC 379', 'IPC 307', 'Narcotics Act']" "['IPC 307', 'Cyber Laws']"
#  "['IPC 420', 'IPC 302', 'Economic Offenses Act']"
#  "['IPC 302', 'IPC 420', 'Cyber Laws']" "['IPC 302', 'IPC 302']"
#  "['Cyber Laws', 'Economic Offenses Act', 'IPC 307']"
#  "['IPC 379', 'IPC 307']"
#  "['IPC 302', 'IPC 307', 'Economic Offenses Act']"
#  "['Cyber Laws', 'IPC 420', 'IPC 307']" "['IPC 420', 'Cyber Laws']"
#  "['Cyber Laws', 'IPC 302', 'Narcotics Act']"
#  "['IPC 307', 'Cyber Laws', 'Economic Offenses Act']"
#  "['IPC 302', 'IPC 420', 'IPC 302']"
#  "['IPC 307', 'Narcotics Act', 'Narcotics Act']"
#  "['Narcotics Act', 'Cyber Laws']"
#  "['Cyber Laws', 'Economic Offenses Act']"
#  "['IPC 420', 'IPC 379', 'Cyber Laws']"
#  "['IPC 420', 'IPC 379', 'IPC 307']"
#  "['Economic Offenses Act', 'IPC 379', 'Economic Offenses Act']"
#  "['Narcotics Act', 'Narcotics Act', 'IPC 302']"
#  "['Economic Offenses Act', 'Cyber Laws', 'IPC 379']"
#  "['Narcotics Act', 'Cyber Laws', 'Economic Offenses Act']"
#  "['IPC 307', 'IPC 307', 'IPC 379']" "['IPC 379', 'IPC 379', 'IPC 307']"
#  "['Cyber Laws', 'IPC 420']"
#  "['IPC 379', 'Economic Offenses Act', 'Economic Offenses Act']"
#  "['IPC 379', 'Narcotics Act']"
#  "['IPC 420', 'Narcotics Act', 'Cyber Laws']"
#  "['Narcotics Act', 'IPC 307', 'Economic Offenses Act']"
#  "['IPC 379', 'Economic Offenses Act']"
#  "['IPC 302', 'Economic Offenses Act', 'Cyber Laws']"
#  "['Narcotics Act', 'IPC 420', 'Cyber Laws']"
#  "['IPC 302', 'Economic Offenses Act', 'IPC 302']"
#  "['Economic Offenses Act', 'IPC 420']"
#  "['Economic Offenses Act', 'IPC 379', 'IPC 302']"
#  "['Narcotics Act', 'IPC 302']"
#  "['IPC 379', 'Economic Offenses Act', 'Cyber Laws']"
#  "['IPC 302', 'IPC 307', 'Narcotics Act']"
#  "['IPC 302', 'Cyber Laws', 'Cyber Laws']"
#  "['Economic Offenses Act', 'Economic Offenses Act']"
#  "['IPC 302', 'Cyber Laws']" "['Cyber Laws', 'Cyber Laws']"
#  "['IPC 379', 'Economic Offenses Act', 'IPC 420']"
#  "['IPC 307', 'IPC 302', 'Narcotics Act']" "['IPC 420', 'IPC 302']"
#  "['IPC 420', 'IPC 307', 'IPC 307']" "['IPC 302', 'IPC 379']"
#  "['Cyber Laws', 'Economic Offenses Act', 'Economic Offenses Act']"
#  "['IPC 379', 'IPC 420']" "['IPC 307', 'Narcotics Act', 'IPC 302']"
#  "['IPC 379', 'IPC 302', 'Narcotics Act']"
#  "['IPC 307', 'IPC 302', 'Economic Offenses Act']"
#  "['Economic Offenses Act', 'IPC 302']"
#  "['Cyber Laws', 'IPC 302', 'IPC 302']"
#  "['Narcotics Act', 'Economic Offenses Act', 'Cyber Laws']"
#  "['IPC 379', 'IPC 379']"
#  "['IPC 302', 'Economic Offenses Act', 'Narcotics Act']"
#  "['IPC 420', 'IPC 302', 'IPC 307']"
#  "['Cyber Laws', 'Economic Offenses Act', 'IPC 420']"
#  "['IPC 302', 'IPC 379', 'IPC 307']"
#  "['IPC 379', 'Narcotics Act', 'IPC 379']"
#  "['IPC 420', 'IPC 307', 'IPC 420']"
#  "['IPC 302', 'Economic Offenses Act', 'Economic Offenses Act']"
#  "['IPC 307', 'IPC 379', 'Cyber Laws']"
#  "['IPC 302', 'IPC 420', 'IPC 379']"
#  "['Narcotics Act', 'Economic Offenses Act', 'Narcotics Act']"
#  "['Economic Offenses Act', 'IPC 379', 'Narcotics Act']"
#  "['IPC 420', 'IPC 420', 'IPC 302']"
#  "['IPC 307', 'Economic Offenses Act', 'IPC 420']"
#  "['IPC 302', 'Narcotics Act']"
#  "['Cyber Laws', 'Economic Offenses Act', 'IPC 379']"
#  "['IPC 302', 'IPC 420', 'Narcotics Act']" "['IPC 307', 'IPC 379']"
#  "['Economic Offenses Act', 'Cyber Laws', 'IPC 302']"
#  "['Economic Offenses Act', 'IPC 379', 'IPC 420']"
#  "['IPC 379', 'Cyber Laws', 'Economic Offenses Act']"
#  "['Cyber Laws', 'IPC 302', 'IPC 379']"
#  "['IPC 420', 'Economic Offenses Act', 'IPC 302']"
#  "['Economic Offenses Act', 'IPC 420', 'Cyber Laws']"
#  "['Narcotics Act', 'IPC 379', 'IPC 302']"
#  "['Cyber Laws', 'Cyber Laws', 'IPC 302']"
#  "['IPC 420', 'IPC 420', 'IPC 307']"
#  "['Economic Offenses Act', 'Economic Offenses Act', 'Narcotics Act']"
#  "['IPC 379', 'Cyber Laws', 'IPC 307']"
#  "['IPC 302', 'IPC 307', 'IPC 302']"
#  "['IPC 420', 'Cyber Laws', 'IPC 420']"
#  "['Economic Offenses Act', 'IPC 420', 'IPC 420']"
#  "['Cyber Laws', 'Cyber Laws', 'Cyber Laws']"
#  "['IPC 420', 'IPC 307', 'IPC 302']"
#  "['Cyber Laws', 'IPC 379', 'Narcotics Act']"
#  "['IPC 420', 'Narcotics Act', 'Narcotics Act']"
#  "['IPC 420', 'IPC 307', 'Narcotics Act']"
#  "['Economic Offenses Act', 'Cyber Laws']"
#  "['IPC 302', 'Economic Offenses Act', 'IPC 420']"
#  "['IPC 420', 'IPC 379', 'IPC 420']"
#  "['Cyber Laws', 'IPC 307', 'IPC 302']"
#  "['IPC 379', 'IPC 302', 'Economic Offenses Act']"
#  "['Narcotics Act', 'Economic Offenses Act', 'IPC 302']"
#  "['IPC 307', 'IPC 379', 'IPC 302']"
#  "['IPC 420', 'Narcotics Act', 'IPC 302']"
#  "['Narcotics Act', 'IPC 307', 'IPC 420']" "['IPC 420', 'IPC 379']"
#  "['Economic Offenses Act', 'Economic Offenses Act', 'IPC 379']"
#  "['IPC 379', 'IPC 379', 'Narcotics Act']"
#  "['Cyber Laws', 'IPC 420', 'IPC 302']"
#  "['Economic Offenses Act', 'IPC 420', 'IPC 379']"
#  "['IPC 307', 'IPC 379', 'IPC 420']"
#  "['Narcotics Act', 'IPC 302', 'IPC 379']"
#  "['Narcotics Act', 'IPC 420', 'Narcotics Act']"
#  "['Narcotics Act', 'IPC 307', 'IPC 379']"
#  "['Economic Offenses Act', 'IPC 420', 'Narcotics Act']"
#  "['IPC 307', 'IPC 420', 'IPC 420']"
#  "['IPC 302', 'Cyber Laws', 'Economic Offenses Act']"
#  "['IPC 379', 'IPC 379', 'IPC 302']" "['IPC 307', 'IPC 302', 'IPC 379']"
#  "['IPC 307', 'IPC 420', 'IPC 379']"
#  "['Economic Offenses Act', 'Economic Offenses Act', 'IPC 420']"
#  "['Narcotics Act', 'IPC 379', 'Economic Offenses Act']"
#  "['Cyber Laws', 'IPC 379', 'IPC 379']"
#  "['Economic Offenses Act', 'IPC 379']"
#  "['IPC 307', 'Economic Offenses Act', 'Economic Offenses Act']"
#  "['IPC 379', 'IPC 379', 'Cyber Laws']"
#  "['Economic Offenses Act', 'IPC 420', 'IPC 307']"
#  "['Economic Offenses Act', 'Cyber Laws', 'IPC 307']"
#  "['Cyber Laws', 'Cyber Laws', 'Economic Offenses Act']"
#  "['IPC 307', 'IPC 420', 'Economic Offenses Act']"
#  "['Cyber Laws', 'IPC 307', 'IPC 307']"
#  "['Narcotics Act', 'IPC 302', 'IPC 307']"
#  "['Economic Offenses Act', 'Narcotics Act', 'Narcotics Act']"
#  "['IPC 302', 'IPC 420', 'Economic Offenses Act']"
#  "['IPC 379', 'IPC 420', 'Narcotics Act']"
#  "['IPC 302', 'Narcotics Act', 'IPC 307']"
#  "['IPC 307', 'IPC 302', 'IPC 302']"
#  "['IPC 379', 'Narcotics Act', 'IPC 302']"
#  "['Cyber Laws', 'IPC 302', 'IPC 420']"
#  "['IPC 302', 'IPC 420', 'IPC 307']"
#  "['Narcotics Act', 'IPC 302', 'IPC 302']"
#  "['IPC 420', 'Economic Offenses Act', 'IPC 379']"
#  "['Narcotics Act', 'IPC 379', 'IPC 379']"
#  "['IPC 302', 'IPC 302', 'Economic Offenses Act']"
#  "['IPC 302', 'Cyber Laws', 'IPC 307']"
#  "['Narcotics Act', 'IPC 307', 'Narcotics Act']"
#  "['IPC 420', 'IPC 420', 'Cyber Laws']"
#  "['Economic Offenses Act', 'Economic Offenses Act', 'Cyber Laws']"
#  "['Narcotics Act', 'IPC 307', 'IPC 307']"
#  "['IPC 302', 'IPC 379', 'IPC 420']"
#  "['IPC 307', 'Cyber Laws', 'IPC 302']"
#  "['IPC 307', 'IPC 379', 'IPC 379']"
#  "['Narcotics Act', 'IPC 379', 'IPC 420']"
#  "['Economic Offenses Act', 'Economic Offenses Act', 'Economic Offenses Act']"
#  "['Cyber Laws', 'Narcotics Act', 'Cyber Laws']"
#  "['Economic Offenses Act', 'Cyber Laws', 'Narcotics Act']"
#  "['IPC 302', 'Narcotics Act', 'Narcotics Act']"
#  "['IPC 307', 'IPC 307', 'Cyber Laws']"
#  "['IPC 379', 'Cyber Laws', 'IPC 302']"
#  "['Economic Offenses Act', 'Economic Offenses Act', 'IPC 307']"
#  "['IPC 302', 'IPC 379', 'Narcotics Act']"
#  "['Cyber Laws', 'IPC 302', 'Economic Offenses Act']"
#  "['IPC 307', 'Economic Offenses Act', 'Narcotics Act']"
#  "['Narcotics Act', 'IPC 379', 'Cyber Laws']"
#  "['IPC 379', 'IPC 420', 'IPC 379']" "['IPC 307', 'IPC 302', 'IPC 420']"
#  "['IPC 420', 'IPC 420', 'Economic Offenses Act']"
#  "['IPC 420', 'IPC 302', 'Narcotics Act']"
#  "['IPC 379', 'IPC 307', 'IPC 307']"
#  "['IPC 420', 'IPC 379', 'Economic Offenses Act']"
#  "['IPC 302', 'IPC 302', 'IPC 420']" "['IPC 302', 'IPC 307', 'IPC 420']"
#  "['IPC 420', 'IPC 302', 'IPC 379']"
#  "['Economic Offenses Act', 'IPC 420', 'Economic Offenses Act']"
#  "['IPC 302', 'IPC 302', 'Cyber Laws']"
#  "['Narcotics Act', 'Cyber Laws', 'IPC 379']"
#  "['IPC 379', 'Cyber Laws', 'IPC 379']"
#  "['IPC 302', 'IPC 420', 'IPC 420']"
#  "['Narcotics Act', 'Economic Offenses Act', 'IPC 420']"
#  "['Cyber Laws', 'IPC 420', 'IPC 420']"
#  "['IPC 379', 'Narcotics Act', 'Economic Offenses Act']"
#  "['IPC 307', 'Economic Offenses Act', 'IPC 302']"
#  "['IPC 307', 'IPC 420', 'IPC 302']"
#  "['Narcotics Act', 'IPC 302', 'Economic Offenses Act']"
#  "['IPC 307', 'Economic Offenses Act', 'IPC 307']"
#  "['Narcotics Act', 'Narcotics Act', 'IPC 379']"
#  "['IPC 379', 'Cyber Laws', 'Cyber Laws']"
#  "['IPC 420', 'IPC 420', 'IPC 379']"
#  "['Cyber Laws', 'IPC 379', 'IPC 307']"
#  "['IPC 379', 'Narcotics Act', 'IPC 307']"
#  "['Cyber Laws', 'IPC 379', 'IPC 302']"
#  "['IPC 302', 'IPC 307', 'IPC 307']"
#  "['Cyber Laws', 'IPC 307', 'Economic Offenses Act']"
#  "['IPC 420', 'Economic Offenses Act', 'Economic Offenses Act']"
#  "['Cyber Laws', 'Cyber Laws', 'Narcotics Act']"
#  "['IPC 420', 'IPC 379', 'IPC 379']"
#  "['IPC 420', 'Narcotics Act', 'IPC 379']"
#  "['Economic Offenses Act', 'IPC 379', 'IPC 307']"
#  "['IPC 379', 'Narcotics Act', 'Narcotics Act']"
#  "['Economic Offenses Act', 'IPC 379', 'Cyber Laws']"
#  "['IPC 379', 'Narcotics Act', 'IPC 420']"
#  "['IPC 302', 'Narcotics Act', 'Cyber Laws']"
#  "['Cyber Laws', 'Cyber Laws', 'IPC 379']"
#  "['Narcotics Act', 'Economic Offenses Act', 'Economic Offenses Act']"
#  "['IPC 420', 'Narcotics Act', 'IPC 307']"
#  "['Economic Offenses Act', 'IPC 302', 'Economic Offenses Act']"
#  "['Narcotics Act', 'Cyber Laws', 'Cyber Laws']"
#  "['Narcotics Act', 'IPC 420', 'IPC 379']"
#  "['IPC 379', 'Cyber Laws', 'Narcotics Act']"
#  "['Economic Offenses Act', 'IPC 307', 'IPC 302']"
#  "['IPC 307', 'Narcotics Act', 'IPC 307']"
#  "['IPC 302', 'Cyber Laws', 'Narcotics Act']"
#  "['IPC 420', 'IPC 379', 'Narcotics Act']"
#  "['IPC 379', 'IPC 420', 'IPC 302']"
#  "['Economic Offenses Act', 'Narcotics Act', 'Economic Offenses Act']"
#  "['IPC 307', 'IPC 307', 'IPC 302']"
#  "['IPC 307', 'Cyber Laws', 'IPC 307']"
#  "['Narcotics Act', 'Cyber Laws', 'Narcotics Act']"
#  "['IPC 420', 'IPC 379', 'IPC 302']"
#  "['Economic Offenses Act', 'IPC 307', 'IPC 420']"
#  "['Narcotics Act', 'Narcotics Act', 'IPC 307']"
#  "['Cyber Laws', 'IPC 379', 'IPC 420']"
#  "['IPC 307', 'Narcotics Act', 'IPC 379']"
#  "['Narcotics Act', 'Narcotics Act', 'Cyber Laws']"
#  "['Economic Offenses Act', 'IPC 307', 'Narcotics Act']"
#  "['IPC 420', 'IPC 307', 'IPC 379']" "['IPC 379', 'IPC 302', 'IPC 420']"
#  "['IPC 420', 'IPC 302', 'IPC 302']"
#  "['Cyber Laws', 'IPC 302', 'IPC 307']"
#  "['IPC 307', 'IPC 379', 'Narcotics Act']"
#  "['Economic Offenses Act', 'IPC 302', 'IPC 302']"
#  "['IPC 379', 'IPC 379', 'Economic Offenses Act']"
#  "['IPC 420', 'Economic Offenses Act', 'Cyber Laws']"
#  "['IPC 420', 'Narcotics Act', 'IPC 420']"
#  "['IPC 420', 'IPC 307', 'Cyber Laws']"
#  "['Economic Offenses Act', 'IPC 302', 'IPC 420']"
#  "['IPC 379', 'Economic Offenses Act', 'Narcotics Act']"
#  "['Narcotics Act', 'Economic Offenses Act', 'IPC 379']"
#  "['IPC 307', 'IPC 307', 'IPC 420']"
#  "['Cyber Laws', 'IPC 307', 'Narcotics Act']"
#  "['IPC 307', 'Narcotics Act', 'Economic Offenses Act']"
#  "['IPC 379', 'IPC 420', 'IPC 307']"
#  "['Cyber Laws', 'IPC 307', 'IPC 379']"
#  "['Cyber Laws', 'Cyber Laws', 'IPC 420']"
#  "['IPC 420', 'Cyber Laws', 'Economic Offenses Act']"
#  "['Cyber Laws', 'IPC 307', 'IPC 420']"
#  "['IPC 379', 'IPC 307', 'IPC 420']"
#  "['Economic Offenses Act', 'Cyber Laws', 'Economic Offenses Act']"
#  "['Cyber Laws', 'IPC 420', 'Economic Offenses Act']"
#  "['IPC 379', 'Economic Offenses Act', 'IPC 307']"
#  "['Cyber Laws', 'Economic Offenses Act', 'Narcotics Act']"
#  "['IPC 302', 'IPC 307', 'Cyber Laws']"
#  "['IPC 379', 'Economic Offenses Act', 'IPC 302']"
#  "['IPC 420', 'Economic Offenses Act', 'Narcotics Act']"
#  "['IPC 379', 'IPC 379', 'IPC 379']" "['IPC 420', 'IPC 420', 'IPC 420']"
#  "['IPC 302', 'IPC 302', 'IPC 307']"
#  "['Economic Offenses Act', 'IPC 307', 'IPC 307']"
#  "['IPC 307', 'Cyber Laws', 'IPC 420']"
#  "['Cyber Laws', 'Economic Offenses Act', 'Cyber Laws']"
#  "['IPC 307', 'Economic Offenses Act', 'IPC 379']"
#  "['IPC 379', 'IPC 302', 'IPC 379']" "['IPC 302', 'IPC 379', 'IPC 379']"
#  "['Economic Offenses Act', 'IPC 302', 'IPC 379']"
#  "['Cyber Laws', 'IPC 379', 'Economic Offenses Act']"
#  "['IPC 307', 'IPC 420', 'Narcotics Act']"
#  "['IPC 307', 'Cyber Laws', 'Cyber Laws']"
#  "['IPC 302', 'Narcotics Act', 'IPC 302']"
#  "['Narcotics Act', 'IPC 307', 'IPC 302']"
#  "['IPC 307', 'IPC 307', 'Economic Offenses Act']"
#  "['IPC 420', 'Economic Offenses Act', 'IPC 307']"
#  "['IPC 307', 'IPC 307', 'IPC 307']"
#  "['IPC 379', 'IPC 307', 'Economic Offenses Act']"
#  "['IPC 420', 'IPC 307', 'Economic Offenses Act']"
#  "['Narcotics Act', 'Cyber Laws', 'IPC 302']"
#  "['IPC 302', 'Cyber Laws', 'IPC 379']"
#  "['IPC 379', 'IPC 420', 'IPC 420']"
#  "['IPC 379', 'Narcotics Act', 'Cyber Laws']"
#  "['Economic Offenses Act', 'IPC 302', 'Narcotics Act']"
#  "['IPC 307', 'Narcotics Act', 'Cyber Laws']"
#  "['Narcotics Act', 'Economic Offenses Act', 'IPC 307']"
#  "['Narcotics Act', 'Narcotics Act', 'Narcotics Act']"]
# Categories in'parental level of education' Prior_Criminal_History: [0 1]
# Categories in 'Influence_on_Trial' variable:      [0.11567522 0.94626449 0.73336151 ... 0.94505055 0.54820377 0.95317754]
# Categories in 'Bail_Decision' variable:      ['Rejected' 'Granted']
# Categories in 'Socio_Economic_Status' variable:      ['Low' 'High' 'Middle']

# %%
numeric_feature  = [feature for feature in df.columns if df[feature].dtype!= 'O']
categorical_feature = [feature for feature in df.columns if df[feature].dtype== 'O']
print('Numerical feature we have are: {}'.format( numeric_feature))
print('\nCategorical features we have are: {}'.format (categorical_feature))
# Out:
# Numerical feature we have are: ['Time_Served_Months', 'Prior_Criminal_History', 'Risk_of_Flight', 'Influence_on_Trial']
#
# Categorical features we have are: ['Crime_Type', 'Charges_Filed', 'Bail_Decision', 'Socio_Economic_Status']

# %%
df.to_csv('modified_bail_dataset.csv')

# %% [markdown]
# Feature Selection
